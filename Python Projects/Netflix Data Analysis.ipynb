# %% [markdown]
# ### This netflix dataset has information of movies and TV shows untill 2021, the data set is available on Kaggle.com

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %%
#import dataset
NET_data = pd.read_csv(r"C:\Users\Oluchukwu Anene\Downloads\8. Netflix Dataset.csv")

# %%
#view data
NET_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### Getting to know the dataset
# ##### Data Wrangling

# %%
#The Head function 
NET_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#The Tail function 
NET_data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
#The shape function shows the no. of rows and columns contained in this data
NET_data.shape
# Out:
# (7789, 11)

# %%
#The size function shows the size of the data
NET_data.size
# Out:
# 85679

# %%
#This function is used to show the column name
NET_data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#datatypes
NET_data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#The info function
NET_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# * From the row counts there are some null values in this dataset no. 3-6

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### Finding the duplicate records and null values

# %%
NET_data.duplicated() #function to find duplicate values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %% [markdown]
# * This function only retuned the top 5 rows and the bottom 5 rows its has not give the necessary information required to dictect the duplicate values in a dataset

# %%
NET_data[NET_data.duplicated()] #This fomular will only give data that contain duplicate values
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# * There are only 2 duplicats found in this data set

# %%
NET_data.drop_duplicates(inplace = True)  
#this function removes duplicate values, using this alone 'NET_data.drop_duplicates()' cannot permanently remove the duplicte values, adding (inplace =true) will get it done

# %%
#verify that duplicate values has been removed
NET_data.shape
# Out:
# (7787, 11)

# %% [markdown]
# * Perviously the rows were 7789 in total now they are 7787.

# %% [markdown]
# #### Finding Null Values

# %%
#Using isnull function will return the a series of boolean values to confirm null areas
NET_data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
NET_data.isnull().sum() #this will generate the total of null values in the dataset
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#using seaborn to vizualize the nullvalues in the data set
import matplotlib.pyplot as plt
sns.heatmap(NET_data.isnull())
plt.show()

# %% [markdown]
# ######  For house of cards,Find the show id and the show's Director

# %%
NET_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
NET_data[NET_data['Title'].isin(['House of Cards'])]    #Using the isin() statement to filter the key word
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
NET_data[NET_data['Title'].str.contains('House of Cards')]    #Using the str.contains() to filter key word
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ##### What year were the higest no. of shows and movie released?

# %%
NET_data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
 pd.to_datetime(NET_data['Release_Date']) #convert release columns into Datetime
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Release_Date, Length: 7787, dtype: datetime64[ns]

# %%
NET_data.dtypes #verify
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
NET_data['Date_Released'] = pd.to_datetime(NET_data['Release_Date']) #save in a new column

# %%
NET_data.dtypes #verify
# Out:
# Show_Id                  object
# Category                 object
# Title                    object
# Director                 object
# Cast                     object
# Country                  object
# Release_Date             object
# Rating                   object
# Duration                 object
# Type                     object
# Description              object
# Date_Released    datetime64[ns]
# dtype: object

# %%
NET_data['Date_Released'].dt.year.value_counts()   #the value_counts()function helps to count distinct values in the mentioned column
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_Released, dtype: int64

# %% [markdown]
# * Year 2019 has the highest number of movies and show realeses with 2153 in total

# %% [markdown]
# ##### Using a Bar chart

# %%
NET_data['Date_Released'].dt.year.value_counts().plot(kind ='bar', color= 'navy') 
plt.title("Frequency of Release Year", fontsize=20)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %% [markdown]
# ##### How many movies and tv shows are in the dataset

# %%
NET_data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(NET_data['Category'])
# Out:
# C:\Users\Oluchukwu Anene\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
NET_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ##### What movies where released in  year 2000?

# %%
NET_data['Years']= NET_data['Date_Released'].dt.year

# %%
NET_data [(NET_data['Category']== 'Movie') & (NET_data['Years']== 2015)]  #Filtering
# Out:
#      Show_Id Category                                              Title  \
# 128     s129    Movie                                            6 Years
# 247     s248    Movie                            A Very Murray Christmas
# 316     s317    Movie                                       Advantageous
# 535     s536    Movie                         Anjelah Johnson: Not Fancy
# 551     s552    Movie             Anthony Jeselnik: Thoughts and Prayers
# 648     s649    Movie          Aziz Ansari Live at Madison Square Garden
# 785     s786    Movie                                Beasts of No Nation
# 1013   s1014    Movie                                Bob's Broken Sleigh
# 1352   s1353    Movie                         Chris D'Elia: Incorrigible
# 1357   s1358    Movie                                  Chris Tucker Live
# 1394   s1395    Movie                                             Circle
# 1513   s1514    Movie              Cowspiracy: The Sustainability Secret
# ...

# %% [markdown]
# ##### Titles of TV shows realsed in France.

# %%
NET_data [(NET_data['Category']== 'TV Show') & (NET_data['Country']== 'France')] #Filtering
# Out:
#      Show_Id Category                                  Title  \
# 248     s249  TV Show                  A Very Secret Service
# 303     s304  TV Show                               Ad Vitam
# 1180   s1181  TV Show                         Call My Agent!
# 1201   s1202  TV Show                               Cannabis
# 1536   s1537  TV Show                             Crime Time
# 1933   s1934  TV Show  Einsatzgruppen: The Nazi Death Squads
# 2105   s2106  TV Show                        Family Business
# 2117   s2118  TV Show                        Fary : Hexagone
# 2543   s2544  TV Show                 Grizzy et les Lemmings
# 2563   s2564  TV Show                                      H
# 3002   s3003  TV Show                      Inhuman Resources
# 3498   s3499  TV Show                               La Mante
# 3502   s3503  TV Show                          La Révolution
# 3941   s3942  TV Show                               Marianne
# ...

# %%
NET_data [(NET_data['Category']== 'TV Show') & (NET_data['Country']== 'France')] ['Title'] #filtering Titles only
# Out:
# 248                     A Very Secret Service
# 303                                  Ad Vitam
# 1180                           Call My Agent!
# 1201                                 Cannabis
# 1536                               Crime Time
# 1933    Einsatzgruppen: The Nazi Death Squads
# 2105                          Family Business
# 2117                          Fary : Hexagone
# 2543                   Grizzy et les Lemmings
# 2563                                        H
# 3002                        Inhuman Resources
# 3498                                 La Mante
# 3502                            La Révolution
# 3941                                 Marianne
# 3952                                Marseille
# 4113                                Mini Wolf
# 4167                                   Molang
# 4228                                   Mortel
# 4377                              Mythomaniac
# 4387                        Nailed It! France
# ...

# %%
filtered_data = NET_data[(NET_data['Category']== 'TV Show') & (NET_data['Country']== 'France')]
titles = filtered_data['Title'].values

for i, title in enumerate(titles):
    plt.text(0, i, title, fontsize=12)

plt.yticks([])
plt.title("TV Shows from France", fontsize=15)
plt.show()

# %% [markdown]
# ##### Top 10 Directors with the highest no. of realised TV shows and Movies on Netflix

# %%
NET_data['Director'].value_counts().head(10)     #using value count function and added head(10) to limit output to 10
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
#Plot the bar chart
plt.figure(figsize=(10,4))
NET_data['Director'].value_counts().head(15).plot(kind='bar', color='Teal').set_title('Top 15 Directors With highest TV show on Netflix', fontsize=13)
plt.show()

# %% [markdown]
# ##### Show data, where Categories, Type and country columns are equal to movie, comedy and united kingdom respectivly

# %%
NET_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
N_data =NET_data.dropna()

# %%
NET_data [(NET_data['Category']== 'Movies') &(NET_data['Type']== 'Comedies') | (NET_data['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ##### How many movies and TVshows was Tom Curies cast in?

# %%
N_data [N_data['Cast'].str.contains('Tom Cruise') ]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Date_Released   Years
# 3860  Through chance, human action, past history and...    2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...    2019-07-01  2019.0

# %% [markdown]
# ##### What are the diffrent ratings defined by Netflix?

# %%
NET_data .Rating.nunique()
# Out:
# 14

# %% [markdown]
# ##### How Many movies have the 'TV-14' rating in Canada?

# %%
NET_data .Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
NET_data[(NET_data['Category'] == 'Movies') & (NET_data['Rating'] == 'TV-14') ].shape
# Out:
# (0, 13)

# %%
filtered_data = NET_data[(NET_data['Rating']== 'TV-14') & (NET_data['Country']== 'Canada')]
print(filtered_data.shape[0])
# Out:
# 23

# %% [markdown]
# ##### How Many TV Shows has the "R" Rating after 2018?

# %%
NET_data [(NET_data['Rating']== 'R') &(NET_data['Years']< 2018)]
# Out:
#      Show_Id Category                                  Title  \
# 74       s75    Movie  1898: Our Last Men in the Philippines
# 120     s121    Movie                                 5 to 7
# 190     s191    Movie                       A Kind of Murder
# 599     s600    Movie                                  Asoka
# 629     s630    Movie                               Automata
# ...      ...      ...                                    ...
# 7424   s7423    Movie                        Vincent N Roxxy
# 7529   s7528    Movie                    Welcome to New York
# 7591   s7590    Movie                      While We're Young
# 7689   s7688    Movie                                     XX
# 7692   s7691    Movie                      Y Tu Mamá También
#
#                                                Director  \
# 74                                       Salvador Calvo
# 120                                        Victor Levin
# 190                                        Andy Goddard
# ...

# %% [markdown]
# ##### Find the maximum duration of a Movie or Show in Netflix.

# %%
NET_data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
NET_data[['Minutes','Unit']]= NET_data['Duration'].str.split(' ', expand = True)

# %%
NET_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#
NET_data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# ##### What Country has the highest no. of TV shows

# %%
NET_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_Released   Years  \
# 0  In a future where the elite inhabit an island ...    2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...    2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
NET_dataTV=NET_data[NET_data['Category']== 'TV Show']

# %%
NET_dataTV.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description Date_Released   Years  \
# 0  In a future where the elite inhabit an island ...    2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm...    2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
NET_dataTV['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
NET_dataTV['Country'].value_counts().head()
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: Country, dtype: int64

# %%
#Plot Bar
plt.figure(figsize=(10,4))
sns.countplot(x='Country', data=NET_data, order=NET_data['Country'].value_counts().head().index)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.title("Top 5 Frequent Countries", fontsize=15)
plt.show()

# %% [markdown]
# ##### Sort the Dataset by year

# %%
NET_data.sort_values(by = 'Years').head(2)
# Out:
#      Show_Id Category                 Title              Director  \
# 7115   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show       Dinner for Five                   NaN
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
#
#           Release_Date Rating  Duration  \
# 7115   January 1, 2008  TV-MA    81 min
# 1765  February 4, 2008  TV-MA  1 Season
#
#                                        Type  \
# 7115  Dramas, Independent Movies, Thrillers
# 1765           Stand-Up Comedy & Talk Shows
#
#                                             Description Date_Released   Years  \
# 7115  While covering a story in New York City, a Sea...    2008-01-01  2008.0
# 1765  In each episode, four celebrities join host Jo...    2008-02-04  2008.0
#
#      Minutes    Unit
# 7115      81     min
# ...

# %%
NET_data.sort_values(by = 'Years', ascending = False).head(2)
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
#
#                                                 Country     Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia  January 1, 2021
# 5919                                      United States  January 1, 2021
#
#      Rating Duration                                               Type  \
# 5564  PG-13  128 min                       Action & Adventure, Comedies
# 5919     PG   86 min  Children & Family Movies, Comedies, Sports Movies
#
#                                             Description Date_Released   Years  \
# ...
